# %% [markdown]
# <a href="https://colab.research.google.com/github/BrockDSL/Analyzing_Web_Archives/blob/main/Prep_Muni_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![dsl_logo.png](https://raw.githubusercontent.com/BrockDSL/Analyzing_Web_Archives/main/dsl_logo.png)
#
#
#
# # Analyzing Web Archives
#
# Welcome to the Digital Scholarship Lab Level Analyzing Web Archives workshop.

# %%
import pandas as pd
import gdown
from google.colab import files

#Sentiment just for fun, going to use VADER
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', False)
pd.set_option('display.max_rows', 200)
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
#Need to update to Dec 31 Crawl info
gdown.download('https://drive.google.com/u/0/uc?id=1cvmEiTgbHcdUEOY1oY8bQUHyz-U3HPfV&export=download','web-pages_full.csv.gz',quiet=False)
# !gunzip -k web-pages_full.csv.gz
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1cvmEiTgbHcdUEOY1oY8bQUHyz-U3HPfV&export=download
# To: /content/web-pages_full.csv.gz
# 100%|██████████| 533M/533M [00:05<00:00, 95.0MB/s]

# %%
archive_text = pd.read_csv("web-pages_full.csv")

# %%
archive_text['crawl_date']= pd.to_datetime(archive_text['crawl_date'],format='%Y%m%d')
archive_text = archive_text[archive_text['language'] =='en']

# %%
archive_text.groupby(["domain"]).count().sort_values(by="crawl_date", ascending=False)[0:50]
# Out:
#                               crawl_date     url  mime_type_web_server  \
# domain
# discover.brocku.ca            195595      195595  195595
# gncc.ca                       43862       43862   43862
# youtube.com                   41789       41789   41789
# twitter.com                   30547       30547   30547
# portcolborne.ca               24869       24869   24869
# gobadgers.ca                  18029       18029   18029
# niagaraanglican.ca            16967       16967   16967
# stcatharinesstandard.ca       12213       12213   12213
# niagarahealth.on.ca           12193       12193   12193
# pelhamlibrary.on.ca           10973       10973   10973
# notl.com                      10652       10652   10652
# niagararegion.ca              10165       10165   10165
# exhibits.library.brocku.ca    9118        9118    9118
# thehopecentre.net             8428        8428    8428
# accounts.google.com           7941        7941    7941
# brocku.ca                     7495        7495    7495
# niagarafallsreview.ca         7296        7296    7296
# pinterest.com                 6802        6802    6802
# niagaracollege.ca             5567        5567    5567
# tripadvisor.ca                5456        5456    5456
# eventbrite.ca                 5272        5272    5272
# cbc.ca                        4708        4708    4708
# wainfleet.ca                  3520        3520    3520
# niagarathisweek.com           3206        3206    3206
# thorold.ca                    2495        2495    2495
# covid-19.zoomprospector.com   2358        2358    2358
# mozilla.org                   1753        1753    1753
# pelham.niagaraevergreen.ca    1534        1534    1534
# canada.ca                     1498        1498    1498
# my.nflibrary.ca               1482        1482    1482
# google.com                    1344        1344    1344
# m.youtube.com                 1214        1214    1214
# iheartradio.ca                1008        1008    1008
# mb.moatads.com                990         990     990
# analytics.twitter.com         960         960     960
# sb.freeskreen.com             942         942     942
# who.int                       902         902     902
# emeter-nam.mppapi.io          862         862     862
# canondawndavis.wordpress.com  820         820     820
# mobile.twitter.com            816         816     816
# o2.eyereturn.com              812         812     812
# theglobeandmail.com           792         792     792
# polarcdn-terrax.com           786         786     786
# windstream.net                748         748     748
# chch.com                      703         703     703
# wordpress.com                 689         689     689
# projectshare.ca               682         682     682
# centurylink.net               674         674     674
# theweathernetwork.com         673         673     673
# news.ontario.ca               624         624     624
#
#                               mime_type_tika  language  content
# domain
# discover.brocku.ca            195595          195595    195595
# gncc.ca                       43862           43862     43862
# youtube.com                   41789           41789     41789
# twitter.com                   30547           30547     30547
# portcolborne.ca               24869           24869     24869
# gobadgers.ca                  18029           18029     18029
# niagaraanglican.ca            16967           16967     16967
# stcatharinesstandard.ca       12213           12213     12213
# niagarahealth.on.ca           12193           12193     12193
# pelhamlibrary.on.ca           10973           10973     10973
# notl.com                      10652           10652     10652
# niagararegion.ca              10165           10165     10165
# exhibits.library.brocku.ca    9118            9118      9118
# thehopecentre.net             8428            8428      8428
# accounts.google.com           7941            7941      7941
# brocku.ca                     7495            7495      7495
# niagarafallsreview.ca         7296            7296      7296
# pinterest.com                 6802            6802      6802
# niagaracollege.ca             5567            5567      5567
# tripadvisor.ca                5456            5456      5456
# eventbrite.ca                 5272            5272      5272
# cbc.ca                        4708            4708      4708
# wainfleet.ca                  3520            3520      3520
# niagarathisweek.com           3206            3206      3206
# thorold.ca                    2495            2495      2495
# covid-19.zoomprospector.com   2358            2358      2358
# mozilla.org                   1753            1753      1753
# pelham.niagaraevergreen.ca    1534            1534      1534
# canada.ca                     1498            1498      1498
# my.nflibrary.ca               1482            1482      1482
# google.com                    1344            1344      1344
# m.youtube.com                 1214            1214      1214
# iheartradio.ca                1008            1008      1008
# mb.moatads.com                990             990       990
# analytics.twitter.com         960             960       960
# sb.freeskreen.com             942             942       942
# who.int                       902             902       902
# emeter-nam.mppapi.io          862             862       862
# canondawndavis.wordpress.com  820             820       820
# mobile.twitter.com            816             816       816
# o2.eyereturn.com              812             812       812
# theglobeandmail.com           792             792       792
# polarcdn-terrax.com           786             786       786
# windstream.net                748             748       748
# chch.com                      703             703       703
# wordpress.com                 689             689       689
# projectshare.ca               682             682       682
# centurylink.net               674             674       674
# theweathernetwork.com         673             673       673
# news.ontario.ca               624             624       624

# %%
#Municiple domains into a specific dataframe

municiple_domains = [

  "www.niagararegion.ca",
  "www.notl.com",
  "www.stcatharines.ca",
  "niagarafalls.ca",
  "lincoln.ca",
  "www.forterie.ca",
  "www.grimsby.ca",
  "portcolborne.ca",
  "www.thorold.ca",
  "www.welland.ca",
  "westlincoln.ca",
  "www.wainfleet.ca",
  "www.pelham.ca"
]

muni_text = archive_text[archive_text.domain.isin(municiple_domains)]

# %%
#Add page length
for index, row in muni_text.iterrows():
    muni_text.loc[index,'length'] = int(len(row['content']))
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
#VADER Scoring

muni_text.loc[:,"vscore_pos"] = 0.0
muni_text.loc[:,"vscore_neg"] = 0.0
muni_text.loc[:,"vscore_neu"] = 0.0
muni_text.loc[:,"vscore_compound"] = 0.0


sid = SentimentIntensityAnalyzer()
for index, row in muni_text.iterrows():
    ss = sid.polarity_scores(row["content"])
    muni_text.loc[index,'vscore_pos'] = float(ss["pos"])
    muni_text.loc[index,'vscore_neg'] = float(ss["neg"])
    muni_text.loc[index,'vscore_neu'] = float(ss["neu"])
    muni_text.loc[index,'vscore_compound'] = float(ss["compound"])

# %%
#write of final CSV and download

muni_text.to_csv("municiple_text.csv")
files.download("municiple_text.csv")
